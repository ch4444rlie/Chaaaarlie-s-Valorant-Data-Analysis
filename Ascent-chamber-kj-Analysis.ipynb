# %%
# This notebook analyzes the statistical differences between Killjoy and Chamber
# Data was extracted frin VCT Stage 2, Group Stage on the Map Ascent
# Regions: EMEA, North America, Korea, Brazil, Latan America, Malasia-Singapore
# Analysis was done on May 25, 2022

# %%
import pandas as pd

# %%
df = pd.read_excel("VCT2_chamberkjASCENT.xlsx")

# %%
df_kj = df[ df["Agent"] == "kj"] # dataframe of killjoy only
df_ch = df[ df["Agent"] == "ch"] # dataframe of chamber only

# %%
df_kj.sort_values('ACS', ascending=False)
# Out:
#        Player Region Agent  ACS  ADR   K  KDD
# 20      pr0xy     kr    kj  361  205  24   15
# 53     jans0n     ms    kj  348  238  30   15
# 3   Chronicle   emea    kj  325  196  21   12
# 75      bryce     ms    kj  316  180  25   12
# 48   diewijas     la    kj  307  186  15    1
# 9      dinkzj   emea    kj  289  191  20   10
# 5       trexx   emea    kj  281  189  24    9
# 24      Wenty     kr    kj  269  182  17    4
# 52        Dxn     ms    kj  262  170  21    4
# 41   diewijas     la    kj  259  177  13    9
# 21       k1ng     kr    kj  253  151  18    3
# 58        dxn     ms    kj  237  165  16    2
# 30     prince     br    kj  234  168  12   -3
# 13       dapr     na    kj  222  145  18    1
# 46    jotinha     la    kj  219  146  21   -1
# 73      bryce     ms    kj  213  158  16   -1
# 60      alfin     ms    kj  213  139  22    4
# 36       less     br    kj  211  128  13    8
# 44    jotinha     la    kj  201  137  16    2
# ...

# %%
df_ch.sort_values('ACS', ascending=False)
# Out:
#         Player Region Agent  ACS  ADR   K  KDD
# 18         yay     na    ch  356  215  26   17
# 68        frey     ms    ch  295  188  18    7
# 35        heat     br    ch  264  152  24    9
# 25     Moothie     kr    ch  263  174  23    6
# 62    f0rsaken     ms    ch  262  167  16    7
# 26        BuZz     kr    ch  261  177  17    6
# 54        Frey     ms    ch  253  162  17    9
# 33         frz     br    ch  249  140  20    8
# 27     t3xture     kr    ch  248  145  17    1
# 22        BuZz     kr    ch  247  161  17    4
# 10         yay     na    ch  247  160  19    9
# 19       dicey     na    ch  244  140  17   -1
# 12     Boostio     na    ch  240  164  20    5
# 16         tex     na    ch  235  173  21    7
# 59        frey     ms    ch  232  149  19    5
# 8       ardiis   emea    ch  223  150  14    2
# 6    Chronicle   emea    ch  222  144  17    1
# 43   tacolilla     la    ch  218  160  21    4
# 70        frey     ms    ch  209  122  11    5
# ...

# %%
# Killjoy Summary Statistics

# %%
len(df_kj) # how many times killjoy was used on Ascent
# Out:
# 39

# %%
df_kj.median()
# Out:
# ACS    199.0
# ADR    137.0
# K       14.0
# KDD     -1.0
# dtype: float64

# %%
# Chamber Summary Statistics

# %%
len(df_ch) # how many times chamber was used on Ascent
# Out:
# 37

# %%
df_ch.median()
# Out:
# ACS    209.0
# ADR    140.0
# K       16.0
# KDD      2.0
# dtype: float64
